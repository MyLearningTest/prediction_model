# %%
import pandas as pd
import  matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/Users/haixiangliu/Documents/轮胎_clean.csv')

# %%
df.head()
# Out:
#    是否异常点  实际值                           检测时间  到边的距离  误差值        产线    配方  \
# 0  False  2.2  2018-05-20T09:56:32.000+08:00     10  0.5  B0201005  4262
# 1  False  0.5  2018-05-20T09:56:32.000+08:00    105  0.7  B0201005  4262
# 2   True  4.5  2018-05-20T09:56:32.000+08:00     23  0.5  B0201005  4262
# 3   True  3.7  2018-05-20T09:56:32.000+08:00     79  0.5  B0201005  4262
# 4  False  3.6  2018-05-20T09:56:32.000+08:00     42  0.5  B0201005  4262
#
#    是否左边       标准值      检测时间_NUM      ...       配方.1  配方版本  \
# 0  True  2.113563  1.526778e+09      ...        NaN   A.1
# 1  True  0.489800  1.526778e+09      ...        NaN   A.1
# 2  True  3.924350  1.526778e+09      ...        NaN   A.1
# 3  True  5.009525  1.526778e+09      ...        NaN   A.1
# 4  True  3.875550  1.526778e+09      ...        NaN   A.1
#
#                             采集时间  班次       温度  烟囱胶螺杆速度  上机速度     工单号  \
# 0  2018-05-20T09:56:29.000+08:00   3  59.6926      3.4     6  844368
# ...

# %%
df.describe()
# Out:
#                  实际值          到边的距离            误差值             配方  \
# count  167071.000000  167071.000000  167071.000000  167071.000000
# mean        3.238708      71.125767       0.535262   15699.312801
# std         1.515145      45.914650       0.077418   19310.188877
# min         0.000000       0.000000       0.000000    4005.000000
# 25%         2.500000      32.000000       0.500000    4117.000000
# 50%         3.500000      71.000000       0.500000    4217.000000
# 75%         4.300000     107.000000       0.500000   48003.000000
# max         7.000000     190.000000       0.700000   48109.000000
#
#                  标准值      检测时间_NUM           部件米重             长度        厚度  \
# count  167071.000000  1.670710e+05  167071.000000  167071.000000  167071.0
# mean       -8.380785  1.527512e+09       0.548449    1421.483705       0.0
# std       616.063098  3.684745e+05       0.120003     244.966917       0.0
# ...

# %%
df.std()
# Out:
# 是否异常点              0.257095
# 实际值                1.515145
# 到边的距离             45.914650
# 误差值                0.077418
# 配方             19310.188877
# 是否左边               0.500001
# 标准值              616.063098
# 检测时间_NUM      368474.461876
# 部件米重               0.120003
# 长度               244.966917
# 厚度                 0.000000
# 宽度（内层）            16.294174
# 面积1               99.291856
# 面积2               27.751176
# 重量                 0.168860
# 实际产量             428.150655
# 后测宽A               0.146924
# 后测宽B              16.396448
# 下机速度              18.395026
# 前测宽B              16.796097
# 线速度               17.618655
# 产品编号               7.374848
# 操作工                1.055454
# 计划产量             398.697652
# 配方.1                    NaN
# 班次                 0.799610
# 温度                 0.955566
# 烟囱胶螺杆速度            1.313221
# 上机速度               0.000000
# 工单号            15322.589383
# 采集时间_NUM      368478.309283
# 检测时间_NUM.1    368478.322347
# dtype: float64

# %%
def Sigmoid(x):
    return 1.0 / (1 + np.exp(-x))

# %%
x= np.arange(-10, 10, 0.1)
h = Sigmoid(x)            #Sigmoid函数
plt.plot(x, h)
plt.axvline(0.0, color='k')   #坐标轴上加一条竖直的线（0位置）
plt.axhspan(0.0, 1.0, facecolor='1.0', alpha=1.0, ls='dotted')  
plt.axhline(y=0.5, ls='dotted', color='k')  #在y=0.5的地方加上黑色虚线
plt.yticks([0.0,  0.5, 1.0])  #y轴标度
plt.ylim(-0.1, 1.1)       #y轴范围
plt.show()

# %%
#print(df['是否异常点'])
df2 = df['是否异常点']
#df1 = df-df['是否异常点']
#df1.as_matrix()
#df.as_matrix()
#X=np.array(df1)
#y = np.array(df2)
df2.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: 是否异常点, dtype: bool

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.preprocessing import Imputer

# %%
#Imputer(missing_values='NAN',strategy='mean',axis=0)

# %%
col_n= ['实际值','到边的距离','误差值','配方','是否左边','标准值','部件米重','长度','宽度（内层）','面积1','面积2','重量','实际产量','后测宽A','后测宽B','下机速度','前测宽B','线速度','产品编号','操作工','计划产量','温度','烟囱胶螺杆速度','上机速度']
df1 = pd.DataFrame(df,columns=col_n)
df1.head()
df1.as_matrix()
df2.as_matrix()
X=np.array(df1)
y = np.array(df2)
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """

# %%
df1.head()
# Out:
#    实际值  到边的距离  误差值    配方  是否左边       标准值   部件米重    长度  宽度（内层）    面积1  ...   \
# 0  2.2     10  0.5  4262  True  2.113563  0.392  1699     105  183.8  ...
# 1  0.5    105  0.7  4262  True  0.489800  0.392  1699     105  183.8  ...
# 2  4.5     23  0.5  4262  True  3.924350  0.392  1699     105  183.8  ...
# 3  3.7     79  0.5  4262  True  5.009525  0.392  1699     105  183.8  ...
# 4  3.6     42  0.5  4262  True  3.875550  0.392  1699     105  183.8  ...
#
#     后测宽B   下机速度   前测宽B    线速度  产品编号  操作工  计划产量       温度  烟囱胶螺杆速度  上机速度
# 0  117.0  118.8  120.7  123.3  20.1  4.9   400  59.6926      3.4     6
# 1  117.0  118.8  120.7  123.3  20.1  4.9   400  59.6926      3.4     6
# 2  117.0  118.8  120.7  123.3  20.1  4.9   400  59.6926      3.4     6
# 3  117.0  118.8  120.7  123.3  20.1  4.9   400  59.6926      3.4     6
# 4  117.0  118.8  120.7  123.3  20.1  4.9   400  59.6926      3.4     6
#
# [5 rows x 24 columns]

# %%
model = LogisticRegression()
model.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
model.coef_
# Out:
# array([[-8.07573094e-02, -1.93507715e-03,  4.51058209e-03,
#          5.88584262e-06,  1.18457434e-02, -2.02797210e-02,
#          2.85003363e-05,  3.40685456e-04, -6.47767261e-03,
#          1.67212197e-03,  4.67632799e-06,  1.61528726e-03,
#         -3.32914202e-04, -8.01128549e-04,  3.08593924e-03,
#          2.16644106e-03, -1.13933930e-03,  1.08968711e-03,
#         -1.05404643e-02, -1.22767261e-02, -1.84088713e-04,
#         -4.46558925e-02,  5.83912551e-02, -7.55414867e-03]])

# %%
model.intercept_
# Out:
# array([-0.00125902])
